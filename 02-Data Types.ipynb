# %% [markdown]
# # Basic Data types in Python

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Numbers
#
# Numbers are generally used when we are doing some math operations on it

# %%
# integers

# %%
print(5)
# Out:
# 5

# %%
print(-100)
# Out:
# -100

# %%
type(5)
# Out:
# int

# %%
type(-100)
# Out:
# int

# %%
# float
print(2.3)
# Out:
# 2.3

# %%
print(-100.3)
# Out:
# -100.3

# %%
type(2.3)
# Out:
# float

# %%
type(-100.3)
# Out:
# float

# %% [markdown]
# # Booleans
#
# logical values indicating True or False

# %%
# True or False

# %%
a = True
type(a) ## print(type(True))
# Out:
# bool

# %%
b = False
print(type(b))
# Out:
# <class 'bool'>

# %%
a = 5
print(type(a))
# Out:
# <class 'int'>

# %% [markdown]
# # Strings
#
# Series of characters enclosed withing single or double quotes

# %%
# single quotes

# %%
a = 'hello'
print(a)
b = 'Python'
print(b)
# Out:
# hello
# Python

# %%
# type(a)
type(b)
# Out:
# str

# %%
# double quotes

# %%
a = "hello"
b = "python"
print(a)
print(b)
# Out:
# hello
# python

# %%
# type(a)
type(b)
# Out:
# str

# %%
# required string = I'm Learning python 

# 1) using single quotes
a = 'I\'m Learning python'
print(a)

# 2) using double quotes
b = "I'm Learning python"
print(b)
# Out:
# I'm Learning python
# I'm Learning python

# %%
# len()
# returns the length of the string

a = "Python"
len(a)
# Out:
# 6

# %%
#Note : spaces are also counted
b = 'Welcome to python'
len(b)
# Out:
# 17

# %% [markdown]
# # String indexing
#
# indexing

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # reverse indexing
#
# ![image.png](attachment:image.png)

# %%
# examples on indexing
a = "hello i am sachin"
print(a[0])
# Out:
# h

# %%
print(a[1])
# Out:
# e

# %%
print(a[4])
# Out:
# o

# %%
print(a[-1])
# Out:
# n

# %%
print(a[-2])
# Out:
# i

# %% [markdown]
# # Slicing

# %% [markdown]
# # [start:stop:step]
#
# # start = starting position (default value is 0)
# # stop = end position(exclusive) (default value is end position)
# # step = step size or increment size (default value is 1)

# %%
# examples
a = "hello world"

#to grab "hello"
a[0:5:1] # same as a[:5]
# Out:
# 'hello'

# %%
# to grab 'world'

# 1) using positive indexes
a[6:]
# Out:
# 'world'

# %%
# 2) using negative indexes
a[-5:] # gets the last 5 characters.
# Out:
# 'world'

# %%
# to get alternated characters from the string,specify step = 2
a[::2]
# Out:
# 'hlowrd'

# %%
# to get the reverse of a string
a[::-1]
# Out:
# 'dlrow olleh'

# %% [markdown]
# # Concatination

# %%
str1 = 'A'
str2 = 'B'
str3 = str1+str2
print(str3)
# Out:
# AB

# %%
first_name = 'pranay '
last_name = 'noothi'
full_name = first_name+last_name
print(full_name)
# Out:
# pranay noothi

# %%
# Error
a = 5
b = "hello"
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-15dc5697eb37> in <module>
#       2 a = 5
#       3 b = "hello"
# ----> 4 print(a+b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# # Note : before concatinating, make sure both the variable are of string type. Because string concatination can only be performed with strings ,no other data types can be used to concatinate with the string

# %% [markdown]
# # Immutability

# %%
name = "Tree"

# %%
# cannot change like this.Because strings are immutable
name[0] = "F"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-c853577350ad> in <module>
#       1 # cannot change like this.Because strings are immutable
# ----> 2 name[0] = "F"
#
# TypeError: 'str' object does not support item assignment

# %%
# work around
"F" + name[1:]
# Out:
# 'Free'

# %% [markdown]
# # Some inbuilt functions

# %%
# 1) .upper()
a = 'hello world'
# print(a.upper())

# %%
# 2) .lower()
print(a.lower())
# Out:
# hello world

# %%
# 3) .startswith()
print(a.startswith("j"))
# Out:
# False

# %%
# 4) .endswith()
print(a.endswith('D'))
# Out:
# False

# %%
# 5) .capitalize()
print(a)
print(a.capitalize())
# Out:
# hello world
# Hello world

# %%
# task 1) go through some of the other in built functions

# task 2) 
# given a string for example
str1 = "Welcome to python"

# check if "to" is present in "welcome to python"

# %% [markdown]
# # Ref : Complete Python Bootcamp : Go from zero to hero in Python 3
